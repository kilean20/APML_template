# %% [markdown]
#  # please re-start kernel if these packages are installed for the first time

# %%
# ! pip install -e /user/hwang/Jupyter_notebooks/pkgs/objFuncs_REA
# ! pip install -e /user/hwang/Jupyter_notebooks/pkgs/pyBO

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import time
import datetime
import concurrent
from epics import caget

# %%
from objFuncs.REA_maximize_FC import maximize_FC1058 as maximize_FC
import objFuncs
from objFuncs.util import plot_obj_history
from pyBO import pyBO
# Out:
#    _test : False
#    _ensure_set_timeout : 30
#    _ensure_set_timewait_after_ramp : 0.25
#    _fetch_data_time_span : 2.05
#    _return_obj_var : False
#    _check_chopper_blocking : False
# [15:04:59.883] INFO: phantasy.library.operation.core: Load new machine: 'FRIB', segment: 'LINAC'
# [15:04:59.884] INFO: phantasy.library.parser.config: Importing FRIB from /projects/rea3/AP-ReA/apps/.phyapps/phantasy-machines/FRIB
# [15:04:59.887] INFO: phantasy.library.parser.config: Loading machine configuration from /projects/rea3/AP-ReA/apps/.phyapps/phantasy-machines/FRIB/phantasy.ini
# [15:04:59.889] INFO: phantasy.library.operation.lattice: Loading segment: 'LINAC'
# [15:05:00.081] INFO: phantasy.library.operation.lattice: UNICORN policy will be loaded from /projects/rea3/AP-ReA/apps/.phyapps/phantasy-machines/unicorn/unicorn-data.xls.
# [15:05:00.082] WARNING: phantasy.library.operation.lattice: No aligment data is read.
# [15:05:00.083] INFO: phantasy.library.operation.lattice: Device polarity data is loaded from /projects/rea3/AP-ReA/apps/.phyapps/phantasy-machines/polarity/polarity_data.csv.
# [15:05:00.086] INFO: phantasy.library.operation.lattice: Loading PV data from CSV/SQLite: /projects/rea3/AP-ReA/apps/.phyapps/phantasy-machines/FRIB/linac/all_channels.csv
# [15:05:00.087] INFO: phantasy.library.pv.datasource: Set source to be CSV table: all_channels.csv.
# [15:05:00.654] INFO: phantasy.library.operation.lattice: Model data directory: /user/rea3/phantasy_data/20240326/model_data/data_150500
# [15:05:00.770] INFO: phantasy.library.operation.lattice: Found 13828 PVs in 'LINAC'.
# [15:05:02.905] INFO: phantasy.library.operation.lattice: 'LINAC' has 1353 elements

# %%
from pyBO import pyBO

# %%
objFuncs._global_machineIO._test = False
objFuncs._global_machineIO._fetch_data_time_span = 2.05
objFuncs._global_machineIO._ensure_set_timewait_after_ramp = 0.25
# objFuncs._global_machineIO.fetch_data = objFuncs.construct_machineIO._manual_fetch_data

objFuncs._global_machineIO.view()
# Out:
#    _test : False
#    _ensure_set_timeout : 30
#    _ensure_set_timewait_after_ramp : 0.25
#    _fetch_data_time_span : 2.05
#    _return_obj_var : False
#    _check_chopper_blocking : False
#    _n_popup_ramping_not_OK : 0
#    _verbose : False

# %%
budget = 50

# %%
ion = caget("REA_EXP:ELMT")
Q = int(caget("REA_EXP:Q"))
A = int(caget("REA_EXP:A"))
AQ = A/Q
ion = str(A)+ion+str(Q)
print(ion, 'A/Q=',AQ)
# Out:
# 29Si10 A/Q= 2.9

# %%
now0 = datetime.datetime.now()
now0str = str(now0)[:str(now0).rfind(':')].replace(' ','_').replace(':','').replace('-','')
fname = '[REA][pyBO]'+now0str+'_'+ion+'_FC_CM4in'
fname
# Out:
# '[REA][pyBO]20240326_1505_29Si10_FC_CM4in'

# %% [markdown]
# # Decision parameters and range

# %%
decision_CSETs = ['REA_BTS26:DCH_D1219:I_CSET',
                  'REA_BTS26:DCV_D1219:I_CSET',
                  'REA_BTS30:DCH_D1270:I_CSET',
                  'REA_BTS30:DCV_D1270:I_CSET',
                  ]

# %%
STC = 10.
STC1=STC
STC2=STC
STC3=STC
STC4=STC

decision_min = [-STC1*AQ,-STC2*AQ,-STC3*AQ,-STC4*AQ]
decision_max = [STC1*AQ,STC2*AQ,STC3*AQ,STC4*AQ]

#decision_min = [-50*AQ,-150*AQ,-135*AQ,-135*AQ]
#decision_max = [ 50*AQ, 150*AQ, 135*AQ, 135*AQ]
#decision_tols = None
decision_tols = [1,2,2,2]
print(decision_min)
print(decision_max)
print(decision_tols)
# Out:
# [-29.0, -29.0, -29.0, -29.0]
# [29.0, 29.0, 29.0, 29.0]
# [1, 2, 2, 2]

# %%
assert len(decision_CSETs) == len(decision_min) == len(decision_max)
if decision_tols is not None:
    assert len(decision_CSETs) == len(decision_tols) 
assert np.all(np.array(decision_min)<np.array(decision_max))

# %% [markdown]
# # Objectives

# %% [markdown]
# ### manual definition of obj

# %%
FC0999 = 50e-12
#FC='REA_BTS19:MTER_N0001:I_RD'
FC='REA_BTS40:MTER_N0001:I_RD'
objective_goal   = {FC: {'more than': FC0999}}
objective_weight = {FC: 1}
objective_norm   = {FC: 10e-12}
# objective_goal   = {'REA_WK01:FC_D1058:BC_RD': {'more than': FC0999}}
# objective_weight = {'REA_WK01:FC_D1058:BC_RD': 1}
# objective_norm   = {'REA_WK01:FC_D1058:BC_RD': 1e-12}

# %% [markdown]
# ### regularization

# %%
# reg_goal = {key:0.5*(val_max+val_min) if 'PSD' in key else 0 for key,val_min,val_max in zip(decision_CSETs,decision_min,decision_max)}
# reg_norm = {key:0.5*(val_max-val_min) for key,val_min,val_max in zip(decision_CSETs,decision_min,decision_max)}
# reg_weight = {key:0.1 if 'PSD' in key else 0.05 for key in decision_CSETs}

# %%
# objective_goal.update(reg_goal)
# objective_norm.update(reg_norm)
# objective_weight.update(reg_weight)

# %%
# pd.DataFrame((objective_goal,objective_norm,objective_weight),index=['goal','norm','weight']).T

# %% [markdown]
# ### construct objectives class

# %%
obj = maximize_FC(
    decision_CSETs= decision_CSETs,
    decision_min  = decision_min,
    decision_max  = decision_max,
    decision_tols = decision_tols,
    objective_goal = objective_goal,
    objective_weight = objective_weight,
    objective_norm = objective_norm,
    objective_fill_none_by_init = True,
)
# Out:
# ======== class info ========
# init_time: 2024-03-26 15:07:29.630691
# class_hierarchy: [
#     maximize_FC1058, maximize_FC, objFuncGoals
#     objFuncBase]
# machineIO: <objFuncs.construct_machineIO.construct_machineIO object at 0x7fee21166460>
# decision_CSETs: [
#     REA_BTS26:DCH_D1219:I_CSET, REA_BTS26:DCV_D1219:I_CSET, REA_BTS30:DCH_D1270:I_CSET
#     REA_BTS30:DCV_D1270:I_CSET]
# decision_min: [-29. -29. -29. -29.]
# decision_max: [29. 29. 29. 29.]
# decision_bounds: [[-29.  29.]
#  [-29.  29.]
#  [-29.  29.]
#  [-29.  29.]]
# decision_RDs: [
#     REA_BTS26:DCH_D1219:I_RD, REA_BTS26:DCV_D1219:I_RD, REA_BTS30:DCH_D1270:I_RD
#     REA_BTS30:DCV_D1270:I_RD]
# decision_tols: [1 2 2 2]
# decision_couplings: None
# history_buffer_size: None
# logging_frequency: inf
# logging_tag:
# logging_fname: None
# x0: [-15. -10.  10. -15.]
# objective_weight: {'REA_BTS40:MTER_N0001:I_RD': 1.0}
# objective_goal: {'REA_BTS40:MTER_N0001:I_RD': {'more than': 5e-11}}
# objective_norm: {'REA_BTS40:MTER_N0001:I_RD': 1e-11}
# objective_RDs: [
#     REA_BTS40:MTER_N0001:I_RD]
# objective_p_order: 2
# apply_bilog: False

# %% [markdown]
#  # Prepare plot callbacks

# %%
# define what to plot
plot_CSETs = plot_obj_history(
                obj.history['decision_CSETs'],
                title = 'decision_CSETs',
                inline = True,
                )
plot_RDs = plot_obj_history(
                obj.history['objective_RDs'],
                title = 'objective_RDs',
                inline = True,
                )
plot_objs = plot_obj_history(
            obj.history['objectives'],
            title = 'objectives',
            inline = True,
            )
callbacks = [plot_CSETs,plot_RDs,plot_objs]


# evaluate objective and plot
def obj_callbacks(x):
    return obj(x,callbacks=callbacks)

# %% [markdown]
# # Run BO

# %% [markdown]
# ### Global BO

# %%
bo, X_pending, Y_pending_future = pyBO.runBO(
                                    obj_callbacks,  
                                    bounds=local_bounds,
                                    n_init= int(0.3*budget),
                                    x0 = obj.x0,
                                    budget = int(0.6*budget),
                                    batch_size=1,
                                    path="./log/",
                                    tag=fname+'_pyBO_history',
                                    write_log = False)
for f in callbacks:
    f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 bo, X_pending, Y_pending_future = pyBO.runBO(
#       2                                     obj_callbacks,
#       3                                     bounds=local_bounds,
#       4                                     n_init= int(0.3*budget),
#       5                                     x0 = obj.x0,
#       6                                     budget = int(0.6*budget),
#       7                                     batch_size=1,
#       8                                     path="./log/",
#       9                                     tag=fname+'_pyBO_history',
#      10                                     write_log = False)
#      11 for f in callbacks:
#      12     f.close()
#
# File /projects/rea3/AP-ReA/jupyter-ML/pkgs/pyBO/pyBO/BO.py:88, in runBO(func_obj, bounds, n_init, budget, isfunc_obj_batched, batch_size, x0, y0, model, ramping_rate, polarity_change_time, polarity_penalty, acquisition_func, acquisition_func_args, acquisition_optimize_options, UCB_beta, fixed_values_for_each_dim, scipy_minimize_options, optmization_stopping_criteria, timeout, prior_mean_model, yvar, noise_constraint, path, tag, write_log, callbacks)
#      86     x0, y0 = util.unique_xy(x0,y0)
#      87     if y0 is None:
# ---> 88         y0 = np.atleast_2d(func_obj_batched(x0))
#      89 assert x0.ndim == y0.ndim == 2
#      90 assert y0.shape[1] == 1
#
# File /projects/rea3/AP-ReA/jupyter-ML/pkgs/pyBO/pyBO/BO.py:70, in runBO.<locals>.func_obj_batched(x)
#      68 y = np.zeros((len(x),1))
#      69 for q in range(len(x)):
# ---> 70     y[q] = func_obj(x[q,:])
#      71 return y
#
# Cell In[21], line 22, in obj_callbacks(x)
#      21 def obj_callbacks(x):
# ---> 22     return obj(x,callbacks=callbacks)
#
# File /projects/rea3/AP-ReA/jupyter-ML/pkgs/objFuncs/objFuncs/objFuncs.py:796, in objFuncGoals.__call__(self, x, time_span, abs_z, callbacks)
#     795 def __call__(self,x,time_span=None,abs_z=None, callbacks=None):
# --> 796     self._set_decision(x)
#     797     objs = self._get_object(time_span=time_span,
#     798                             abs_z=abs_z)
#     799     if callbacks is not None:
#
# File /projects/rea3/AP-ReA/jupyter-ML/pkgs/objFuncs/objFuncs/objFuncs.py:379, in objFuncBase._set_decision(self, x)
#     377 assert len(x) == len(self.decision_CSETs)
#     378 if self.decision_couplings is None:
# --> 379     self.machineIO.ensure_set(self.decision_CSETs,self.decision_RDs,x,self.decision_tols)
#     380 else:
#     381     n = len(self.decision_CSETs)
#
# File /projects/rea3/AP-ReA/jupyter-ML/pkgs/objFuncs/objFuncs/construct_machineIO.py:185, in construct_machineIO.ensure_set(self, setpoint_pv, readback_pv, goal, tol, timeout, verbose)
#     183     pass
#     184 elif _phantasy_imported:
# --> 185     _phantasy_ensure_set(setpoint_pv,readback_pv,goal,tol,timeout,verbose=False)
#     186 elif _epics_imported:
#     187     _epics_ensure_set(setpoint_pv,readback_pv,goal,tol,timeout,verbose=False)
#
# File /projects/rea3/AP-ReA/apps/.phyapps/phantasy/phantasy/library/pv/element.py:232, in ensure_set(setpoint_pv, readback_pv, goal, tol, timeout, verbose)
#     229     #return _ensure_set_single(setpoint_pv, readback_pv, goal, tol, timeout, verbose)
#     230 #else:
#     231 assert len(setpoint_pv) == len(readback_pv)
# --> 232 return _ensure_set_array(setpoint_pv, readback_pv, goal, tol, timeout, verbose)
#
# File /projects/rea3/AP-ReA/apps/.phyapps/phantasy/phantasy/library/pv/element.py:319, in _ensure_set_array(setpoint_pvs, readback_pvs, goals, tols, timeout, verbose)
#     317 try:
#     318     if all_done: raise PutFinishedException
# --> 319     all_done, ts = q.get(timeout=timeout)
#     320     if ts - t0 > timeout: raise TimeoutError
#     321 except Empty:
#
# File /usr/lib/python3.9/queue.py:180, in Queue.get(self, block, timeout)
#     178         if remaining <= 0.0:
#     179             raise Empty
# --> 180         self.not_empty.wait(remaining)
#     181 item = self._get()
#     182 self.not_full.notify()
#
# File /usr/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Local BO

# %%
# uncomment and run if more iteration needed
acquisition_func_args = {'beta':9}

n_remain = budget-int(0.3*budget)
betas = np.linspace(9,0.1,n_remain)

for i in range(n_remain):
    x0,y0 = bo.best_sofar()
    local_min = x0 - 0.05*(obj.decision_max - obj.decision_min)
    local_max = x0 + 0.05*(obj.decision_max - obj.decision_min)
    local_bounds = list(zip(local_min,local_max))
    acquisition_func_args['beta'] = betas[i]
    
    X_pending, Y_pending_future= bo.loop( 
                                    n_loop=1,  # number of additional optimization interation
                                    func_obj = obj_callbacks,
                                    X_pending = X_pending, 
                                    Y_pending_future = Y_pending_future,
                                    acquisition_func_args = acquisition_func_args,
                                    batch_size = 1,
                                    write_log = False,
                                    )
for f in callbacks:
    f.close()
# Out:
# [██████████..............................] 25%/100%
# [████████████████████████████████████████] 100%/100%
#
# [████████████████████████████████████████] 100%/100%
#
# [████████████████████████████████████████] 100%/100%
#
# [████████████████████████████████████████] 100%/100%
#
# [████████████████████████████████████████] 100%/100%
#
# [████████████████████████████████████████] 100%/100%
#
# [████████████████████████████████████████] 100%/100%
#
# [████████████████████████████████████████] 100%/100%

# %%
# if python raised error, use the following to re-use all the data until now
# bo, X_pending, Y_pending_future = pyBO.runBO(
#     obj_callbacks,  
#     bounds=obj.decision_bounds,
#     n_init=n_init,
#     x0 = np.array(obj.history['decision_RDs']['values']),
#     y0 = np.array(obj.history['objectives']['values']),
#     budget = budget,
#     batch_size=1,
#     path="./log/",
#     tag=fname+'_pyBO_history',
#     write_log = False)
# for f in callbacks:
#     f.close()

# %%
fig,ax = plt.subplots(figsize=(4,3))
ax = bo.plot_obj_history(ax=ax,plot_best_only=True)
#ax.vlines(n_init,*ax.get_ylim(),color='k')
fig.tight_layout()
# fig.savefig(fname+'_history.png',dpi=90)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 fig,ax = plt.subplots(figsize=(4,3))
#       2 ax = bo.plot_obj_history(ax=ax,plot_best_only=True)
# ----> 3 ax.vlines(n_init,*ax.get_ylim(),color='k')
#       4 fig.tight_layout()
#       5 # fig.savefig(fname+'_history.png',dpi=90)
#
# NameError: name 'n_init' is not defined

# %%
# set to best solution 
x_best,y_best_old = bo.best_sofar()
y_best_new = obj(x_best)
print(x_best,y_best_old[0],y_best_new)   # check if best solution objective value is consistent
# Out:
# [-17.60667421 -15.8          7.4166165   -9.2       ] -4.002233110022331 -3.582452588074526

# %%
now1 = datetime.datetime.now()
now1str = str(now1)[:str(now1).rfind(':')].replace(' ','_').replace(':','').replace('-','')
time_delta = now1 - now0
print("time took:",str(time_delta.total_seconds()/60)[:4],'min')
# Out:
# time took: 6.99 min

# %%
obj.write_log(fname='./log/'+fname)
# Out:
# only .pkl file extension is accepted. saving to: ./log/[REA][pyBO]20240326_1505_29Si10_FC_CM4in.pkl

# %%
# obj_ = objFuncs.objFuncGoals(
#     decision_CSETs= decision_CSETs,
#     decision_min  = decision_min,
#     decision_max  = decision_max,
#     decision_tols = decision_tols,
#     objective_goal = objective_goal,
#     objective_weight = objective_weight,
#     objective_norm = objective_norm,
#     objective_fill_none_by_init = True,
# )

# %% [markdown]
# # Visualize Surrogate model

# %%
# fixed_values_for_each_dim = {2:x_best[2],3:x_best[3]}  # fix values to visualize high dim surrogate model
fixed_values_for_each_dim = None              # do not fix values but project maximum. Can take long time to plot
batch_size = 1

# %%
for i in range(int(len(decision_CSETs)/2)):
    fig,ax = plt.subplots(figsize=(4,3))
    bo.plot_model_2D_projection(project_maximum=True,
                                dim_xaxis = 2*i,
                                dim_yaxis = 2*i+1,
                                grid_ponits_each_dim = 16,
                                fixed_values_for_each_dim=fixed_values_for_each_dim,
                                fig=fig,ax=ax);
    ax.legend()
    pv_x = obj.decision_CSETs[2*i]
    pv_y = obj.decision_CSETs[2*i+1]
    pv_x = pv_x[pv_x.find(':')+1:]
    pv_y = pv_y[pv_y.find(':')+1:]
    pv_x = pv_x[:pv_x.find(':')].replace('_D','')
    pv_y = pv_y[:pv_y.find(':')].replace('_D','')
    ax.set_xlabel(pv_x)
    ax.set_ylabel(pv_y)
    fig.tight_layout()
#     fig.savefig(fname+'_'+pv_x+'_'+pv_y+'_.png',dpi=90)
# Out:
# [████████████████████████████████████████] 100%/100%
#
# [████████████████████████████████████████] 100%/100%

# %%
local_bounds
# Out:
# [(-20.506674206670368, -14.70667420667037),
#  (-18.700000000000003, -12.9),
#  (4.516616503480004, 10.316616503480006),
#  (-12.1, -6.299999999999999)]
